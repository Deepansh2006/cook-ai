# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path().resolve().parent
sys.path.append(str(PROJECT_ROOT))

print("Project root:", PROJECT_ROOT)
# Out:
# Project root: C:\Users\Dell\OneDrive\Desktop\cook-ai\ml-engine

# %%
import pandas as pd

df = pd.read_csv("../data/raw/recipes_small.csv")

print(df.head())
print(df.columns)
print(df.shape)
# Out:
#    RecipeId                                               Name  AuthorId  \
# 0    373686                               Picnic Cowboy Caviar    798690
# 1    406657  Turkey Schnitzel With Tots &amp; Apple-Cranber...    601277
# 2    457811                                     Banilla Splash    169430
# 3    112556                          Easy Tomato Tortilla Soup      2310
# 4        93                             Blue Stuffed Mushrooms      1533
#
#      AuthorName CookTime PrepTime TotalTime         DatePublished  \
# 0        Amy BC     PT1H    PT20M   PT1H20M  2009-05-22T02:13:00Z
# 1  hungrykitten    PT25M    PT15M     PT40M  2010-01-04T08:06:00Z
# 2       Annacia      NaN     PT3M      PT3M  2011-06-02T15:59:00Z
# 3         Geema    PT10M     PT5M     PT15M  2005-03-03T19:59:00Z
# 4        Dancer      NaN    PT15M     PT15M  1999-08-12T06:42:00Z
#
#                                          Description  \
# 0  Make and share this Picnic Cowboy Caviar recip...
# ...

# %%
from src.data_processing.ingredient_normalizer import parse_ingredients

df["cleaned_ingredients"] = df["RecipeIngredientParts"].apply(parse_ingredients)

df[["RecipeIngredientParts","cleaned_ingredients"]].head()
# Out:
#                                RecipeIngredientParts  \
# 0  c("black beans", "black-eyed peas", "white cor...
# 1  c("potatoes", "mcintosh apples", "apple cider"...
# 2                      c("vodka", "cranberry juice")
# 3  c("diced tomatoes with green chilies", "navy b...
# 4  c("blue cheese", "cream cheese", "half-and-hal...
#
#                                  cleaned_ingredients
# 0  [black beans, blackeyed peas, white corn, roma...
# 1  [potatoes, mcintosh apples, apple cider, dried...
# 2                           [vodka, cranberry juice]
# 3  [diced tomatoes with green chilies, navy beans...
# 4  [blue cheese, cream cheese, halfandhalf, mushr...

# %%
output_path = PROJECT_ROOT / "data/processed/recipes_clean.csv"

df.to_csv(output_path, index=False)

print("✅ Saved at:", output_path)
# Out:
# ✅ Saved at: C:\Users\Dell\OneDrive\Desktop\cook-ai\ml-engine\data\processed\recipes_clean.csv
